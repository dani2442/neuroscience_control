# %%
import numpy as np
import os
from scipy.io import loadmat
from dotenv import load_dotenv; load_dotenv()
# %cd {os.getenv('PROJECT_PATH')}
# Out:
# /home/id94ebid/projects/neuroscience_control

# %%
data = []
for i in range(30):
    x = np.load(f"data/ts_young/timeseries_{i}.npy").astype(np.float32)
    data.append(x)

# %%
data = loadmat("data/ts_young/ts_young_TR0.72.mat")

# %%
data['FC_all'].shape
# Out:
# (100, 100, 94)

# %%
data['FC_mean'].shape
# Out:
# (100, 100)

# %%
data['timeseries_all'].shape
# Out:
# (100, 1200, 94)
